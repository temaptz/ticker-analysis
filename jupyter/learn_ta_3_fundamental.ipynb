# %% [markdown]
# # Анализ датасета

# %%
import os
dataset_file_name = 'data_frame_ta_3_fundamental_2026-02-27_12-25-25.csv'
dataset_file_path = os.path.abspath(f'./{dataset_file_name}')
print(dataset_file_path)
# Out:
# /Users/artem/PycharmProjects/ticker-analysis/jupyter/data_frame_ta_3_fundamental_2026-02-27_12-25-25.csv

# %%
import pandas

df = pandas.read_csv(dataset_file_path)

df
# Out:
#      market_capitalization  high_price_last_52_weeks  low_price_last_52_weeks  \
# 0             8.469351e+11                   4575.00                   2453.5
# 1             8.469351e+11                   4575.00                   2453.5
# 2             8.469351e+11                   4575.00                   2453.5
# 3             8.469351e+11                   4575.00                   2453.5
# 4             6.761248e+12                    330.45                    219.2
# ..                     ...                       ...                      ...
# 292           5.366550e+10                    537.75                    242.8
# 293           3.495623e+12                   2629.00                   1617.0
# 294           3.495623e+12                   2629.00                   1617.0
# 295           3.495623e+12                   2629.00                   1617.0
# 296           3.495623e+12                   2629.00                   1617.0
#
#      average_daily_volume_last_10_days  average_daily_volume_last_4_weeks  \
# 0                         1.306560e+06                         1306560.00
# 1                         1.306560e+06                         1306560.00
# 2                         1.306560e+06                         1306560.00
# 3                         1.306560e+06                         1306560.00
# 4                         1.072205e+08                        60056443.16
# ..                                 ...                                ...
# 292                       1.118818e+06                          733070.53
# 293                       1.180965e+06                          879329.05
# 294                       1.180965e+06                          879329.05
# 295                       1.180965e+06                          879329.05
# 296                       1.180965e+06                          879329.05
#
#      beta  shares_outstanding  price_to_book_ttm  total_enterprise_value_mrq  \
# 0    0.72        2.164137e+08              -6.17                3.606121e+11
# 1    0.72        2.164137e+08              -6.17                3.606121e+11
# 2    0.72        2.164137e+08              -6.17                3.606121e+11
# 3    0.72        2.164137e+08              -6.17                3.606121e+11
# 4    0.80        2.158695e+10               1.00                0.000000e+00
# ..    ...                 ...                ...                         ...
# 292  0.40        2.100000e+08               6.63                5.648935e+10
# 293  0.43        1.360694e+09              15.05                4.092398e+12
# 294  0.43        1.360694e+09              15.05                4.092398e+12
# 295  0.43        1.360694e+09              15.05                4.092398e+12
# 296  0.43        1.360694e+09              15.05                4.092398e+12
#
#      total_debt_to_equity_mrq  total_debt_to_ebitda_mrq    ebitda_ttm  \
# 0                      -57.78                       0.0  0.000000e+00
# 1                      -57.78                       0.0  0.000000e+00
# 2                      -57.78                       0.0  0.000000e+00
# 3                      -57.78                       0.0  0.000000e+00
# 4                        0.00                       0.0  0.000000e+00
# ..                        ...                       ...           ...
# 292                     53.02                       0.0  6.533593e+09
# 293                    335.25                       0.0  5.793520e+11
# 294                    335.25                       0.0  5.793520e+11
# 295                    335.25                       0.0  5.793520e+11
# 296                    335.25                       0.0  5.793520e+11
#
#       revenue_ttm  total_debt_mrq  eps_ttm  pe_ratio_ttm  ev_to_ebitda_mrq  \
# 0    0.000000e+00    7.936900e+10     0.00          0.00              0.00
# 1    0.000000e+00    7.936900e+10     0.00          0.00              0.00
# 2    0.000000e+00    7.936900e+10     0.00          0.00              0.00
# 3    0.000000e+00    7.936900e+10     0.00          0.00              0.00
# 4    7.711700e+12    0.000000e+00    73.51          4.26              0.00
# ..            ...             ...      ...           ...               ...
# 292  1.905236e+10    4.289022e+09    23.09         11.07              8.65
# 293  7.564050e+11    7.787280e+11  1320.18         10.44              7.06
# 294  7.564050e+11    7.787280e+11  1320.18         10.44              7.06
# 295  7.564050e+11    7.787280e+11  1320.18         10.44              7.06
# 296  7.564050e+11    7.787280e+11  1320.18         10.44              7.06
#
#      dividend_payout_ratio_fy    result
# 0                        0.00  0.285045
# 1                        0.00  0.265240
# 2                        0.00  0.180375
# 3                        0.00  0.144117
# 4                       45.30  0.121693
# ..                        ...       ...
# 292                     25.09 -0.100450
# 293                     13.62  0.520169
# 294                     13.62  0.480929
# 295                     13.62  0.403659
# 296                     13.62  0.406269
#
# [297 rows x 19 columns]

# %%
df['result'].hist()
# Out:
# <Axes: >

# %%
df.isna().mean().sort_values(ascending=False).head(15)
# Out:
# market_capitalization         0.0
# total_debt_to_ebitda_mrq      0.0
# dividend_payout_ratio_fy      0.0
# ev_to_ebitda_mrq              0.0
# pe_ratio_ttm                  0.0
# eps_ttm                       0.0
# total_debt_mrq                0.0
# revenue_ttm                   0.0
# ebitda_ttm                    0.0
# total_debt_to_equity_mrq      0.0
# high_price_last_52_weeks      0.0
# total_enterprise_value_mrq    0.0
# price_to_book_ttm             0.0
# shares_outstanding            0.0
# beta                          0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   market_capitalization              297 non-null    float64
#  1   high_price_last_52_weeks           297 non-null    float64
#  2   low_price_last_52_weeks            297 non-null    float64
#  3   average_daily_volume_last_10_days  297 non-null    float64
#  4   average_daily_volume_last_4_weeks  297 non-null    float64
#  5   beta                               297 non-null    float64
#  6   shares_outstanding                 297 non-null    float64
#  7   price_to_book_ttm                  297 non-null    float64
#  8   total_enterprise_value_mrq         297 non-null    float64
#  9   total_debt_to_equity_mrq           297 non-null    float64
#  10  total_debt_to_ebitda_mrq           297 non-null    float64
#  11  ebitda_ttm                         297 non-null    float64
#  12  revenue_ttm                        297 non-null    float64
#  13  total_debt_mrq                     297 non-null    float64
#  14  eps_ttm                            297 non-null    float64
#  15  pe_ratio_ttm                       297 non-null    float64
#  16  ev_to_ebitda_mrq                   297 non-null    float64
#  17  dividend_payout_ratio_fy           297 non-null    float64
#  18  result                             297 non-null    float64
# dtypes: float64(19)
# memory usage: 44.2 KB

# %%
df.describe()
# Out:
#        market_capitalization  high_price_last_52_weeks  \
# count           2.970000e+02                297.000000
# mean            6.925766e+11               2698.163098
# std             1.392706e+12               7284.366692
# min             6.366595e+09                  1.140000
# 25%             4.408206e+10                 83.180000
# 50%             1.551440e+11                327.700000
# 75%             5.108955e+11               1333.000000
# max             6.761248e+12              44840.000000
#
#        low_price_last_52_weeks  average_daily_volume_last_10_days  \
# count               297.000000                       2.970000e+02
# mean               1277.673266                       7.889572e+07
# std                3318.359290                       3.650889e+08
# min                   0.470000                       8.721700e+02
# 25%                  41.520000                       7.015855e+05
# 50%                 127.280000                       3.247309e+06
# 75%                 571.000000                       3.212261e+07
# max               20040.000000                       2.916932e+09
#
#        average_daily_volume_last_4_weeks        beta  shares_outstanding  \
# count                       2.970000e+02  297.000000        2.970000e+02
# mean                        5.350194e+07    0.933670        2.194651e+10
# std                         2.609433e+08    0.293277        1.173678e+11
# min                         5.672600e+02    0.080000        1.140300e+06
# 25%                         5.237922e+05    0.800000        1.295000e+08
# 50%                         1.858754e+06    0.990000        6.657339e+08
# 75%                         2.195358e+07    1.150000        5.993227e+09
# max                         2.201453e+09    1.550000        9.944364e+11
#
#        price_to_book_ttm  total_enterprise_value_mrq  \
# count         297.000000                2.970000e+02
# mean            2.106835                6.769492e+11
# std             6.651382                1.442504e+12
# min           -30.280000                0.000000e+00
# 25%             0.390000                2.935642e+10
# 50%             1.170000                1.512206e+11
# 75%             3.040000                7.350965e+11
# max            33.240000                9.716213e+12
#
#        total_debt_to_equity_mrq  total_debt_to_ebitda_mrq    ebitda_ttm  \
# count                 297.00000                     297.0  2.970000e+02
# mean                   56.47798                       0.0  9.687564e+10
# std                   586.69235                       0.0  3.646811e+11
# min                 -3881.14000                       0.0 -8.830284e+09
# 25%                     0.00000                       0.0  0.000000e+00
# 50%                    31.23000                       0.0  0.000000e+00
# 75%                   125.59000                       0.0  3.215500e+10
# max                  1760.57000                       0.0  2.923000e+12
#
#         revenue_ttm  total_debt_mrq      eps_ttm  pe_ratio_ttm  \
# count  2.970000e+02    2.970000e+02   297.000000    297.000000
# mean   9.510775e+11    2.706976e+11   185.362694     10.742593
# std    2.022751e+12    7.918529e+11   479.017452     20.742150
# min   -2.666033e+10    0.000000e+00 -1141.240000      0.000000
# 25%    1.905236e+10    3.519956e+09     0.660000      0.340000
# 50%    1.851421e+11    6.483200e+10    19.830000      4.750000
# 75%    7.564050e+11    2.241480e+11   141.800000     12.250000
# max    1.019600e+13    6.547398e+12  2158.970000    156.080000
#
#        ev_to_ebitda_mrq  dividend_payout_ratio_fy      result
# count        297.000000                297.000000  297.000000
# mean           1.997845                 67.410640   -0.005587
# std            3.798572                324.031199    0.153422
# min           -0.230000                  0.000000   -0.302398
# 25%            0.000000                  0.000000   -0.124846
# 50%            0.000000                  4.110000   -0.028849
# 75%            3.190000                 51.640000    0.085533
# max           23.640000               2812.740000    0.520169

# %%
df['result'].hist()
# Out:
# <Axes: >

# %%
df['price_change_7_month'].hist()
# Out:
# <Axes: >

# %%
df['price_change_7_month'].hist()
df['price_change_8_month'].hist()
df['price_change_9_month'].hist()
df['price_change_10_month'].hist()
df['price_change_11_month'].hist()
df['price_change_1_year'].hist()
df['price_change_2_years'].hist()
df['price_change_3_years'].hist()
# Out:
# <Axes: >

# %%
q1 = df['price_change_7_month'].quantile(.999)
q2 = df['price_change_8_month'].quantile(.996)
q3 = df['price_change_9_month'].quantile(.992)
q4 = df['price_change_10_month'].quantile(.989)
q5 = df['price_change_11_month'].quantile(.987)
q6 = df['price_change_1_year'].quantile(.985)
q7 = df['price_change_2_years'].quantile(.97)
q8 = df['price_change_3_years'].quantile(.999)
q8
# Out:
# 5.9666753

# %%
df[df['price_change_7_month'] < q1]['price_change_7_month'].hist()
df[df['price_change_8_month'] < q2]['price_change_8_month'].hist()
df[df['price_change_9_month'] < q3]['price_change_9_month'].hist()
df[df['price_change_10_month'] < q4]['price_change_10_month'].hist()
df[df['price_change_11_month'] < q5]['price_change_11_month'].hist()
df[df['price_change_1_year'] < q6]['price_change_1_year'].hist()
df[df['price_change_2_years'] < q7]['price_change_2_years'].hist()
df[df['price_change_3_years'] < q8]['price_change_3_years'].hist()
# Out:
# <Axes: >

# %%
df_history_smooth = df[
    (df['price_change_7_month'] < q1) 
    & (df['price_change_8_month'] < q2)
    & (df['price_change_9_month'] < q3)
    & (df['price_change_10_month'] < q4)
    & (df['price_change_11_month'] < q5)
    & (df['price_change_1_year'] < q6)
    & (df['price_change_2_years'] < q7)
    & (df['price_change_3_years'] < q8)
    ].copy()
f'filtered {df.shape[0] - df_history_smooth.shape[0]}'
# Out:
# 'filtered 418357'

# %% [markdown]
# # Подготовка данных для обучения

# %%
df_learn = df.copy()

x = df_learn.drop(columns=['result'])
y = df_learn['result']

x
# Out:
#      market_capitalization  high_price_last_52_weeks  low_price_last_52_weeks  \
# 0             8.469351e+11                   4575.00                   2453.5
# 1             8.469351e+11                   4575.00                   2453.5
# 2             8.469351e+11                   4575.00                   2453.5
# 3             8.469351e+11                   4575.00                   2453.5
# 4             6.761248e+12                    330.45                    219.2
# ..                     ...                       ...                      ...
# 292           5.366550e+10                    537.75                    242.8
# 293           3.495623e+12                   2629.00                   1617.0
# 294           3.495623e+12                   2629.00                   1617.0
# 295           3.495623e+12                   2629.00                   1617.0
# 296           3.495623e+12                   2629.00                   1617.0
#
#      average_daily_volume_last_10_days  average_daily_volume_last_4_weeks  \
# 0                         1.306560e+06                         1306560.00
# 1                         1.306560e+06                         1306560.00
# 2                         1.306560e+06                         1306560.00
# 3                         1.306560e+06                         1306560.00
# 4                         1.072205e+08                        60056443.16
# ..                                 ...                                ...
# 292                       1.118818e+06                          733070.53
# 293                       1.180965e+06                          879329.05
# 294                       1.180965e+06                          879329.05
# 295                       1.180965e+06                          879329.05
# 296                       1.180965e+06                          879329.05
#
#      beta  shares_outstanding  price_to_book_ttm  total_enterprise_value_mrq  \
# 0    0.72        2.164137e+08              -6.17                3.606121e+11
# 1    0.72        2.164137e+08              -6.17                3.606121e+11
# 2    0.72        2.164137e+08              -6.17                3.606121e+11
# 3    0.72        2.164137e+08              -6.17                3.606121e+11
# 4    0.80        2.158695e+10               1.00                0.000000e+00
# ..    ...                 ...                ...                         ...
# 292  0.40        2.100000e+08               6.63                5.648935e+10
# 293  0.43        1.360694e+09              15.05                4.092398e+12
# 294  0.43        1.360694e+09              15.05                4.092398e+12
# 295  0.43        1.360694e+09              15.05                4.092398e+12
# 296  0.43        1.360694e+09              15.05                4.092398e+12
#
#      total_debt_to_equity_mrq  total_debt_to_ebitda_mrq    ebitda_ttm  \
# 0                      -57.78                       0.0  0.000000e+00
# 1                      -57.78                       0.0  0.000000e+00
# 2                      -57.78                       0.0  0.000000e+00
# 3                      -57.78                       0.0  0.000000e+00
# 4                        0.00                       0.0  0.000000e+00
# ..                        ...                       ...           ...
# 292                     53.02                       0.0  6.533593e+09
# 293                    335.25                       0.0  5.793520e+11
# 294                    335.25                       0.0  5.793520e+11
# 295                    335.25                       0.0  5.793520e+11
# 296                    335.25                       0.0  5.793520e+11
#
#       revenue_ttm  total_debt_mrq  eps_ttm  pe_ratio_ttm  ev_to_ebitda_mrq  \
# 0    0.000000e+00    7.936900e+10     0.00          0.00              0.00
# 1    0.000000e+00    7.936900e+10     0.00          0.00              0.00
# 2    0.000000e+00    7.936900e+10     0.00          0.00              0.00
# 3    0.000000e+00    7.936900e+10     0.00          0.00              0.00
# 4    7.711700e+12    0.000000e+00    73.51          4.26              0.00
# ..            ...             ...      ...           ...               ...
# 292  1.905236e+10    4.289022e+09    23.09         11.07              8.65
# 293  7.564050e+11    7.787280e+11  1320.18         10.44              7.06
# 294  7.564050e+11    7.787280e+11  1320.18         10.44              7.06
# 295  7.564050e+11    7.787280e+11  1320.18         10.44              7.06
# 296  7.564050e+11    7.787280e+11  1320.18         10.44              7.06
#
#      dividend_payout_ratio_fy
# 0                        0.00
# 1                        0.00
# 2                        0.00
# 3                        0.00
# 4                       45.30
# ..                        ...
# 292                     25.09
# 293                     13.62
# 294                     13.62
# 295                     13.62
# 296                     13.62
#
# [297 rows x 18 columns]

# %%
import numpy

x_array = x.values
y_array = y.values
count_samples = len(x_array)

random_indexes = numpy.random.permutation(count_samples)

x_array = x_array[random_indexes]
y_array = y_array[random_indexes]

random_indexes
# Out:
# array([175, 259, 209,  72,  34, 150,  19,  54, 128,  87, 263, 162, 228,
#        201, 139, 215, 126, 186, 113, 124,  20, 230, 239, 255, 248, 119,
#         35, 195, 147,  18, 280, 210,  51, 165, 143, 167,   9, 249, 203,
#        233,  84, 163, 168, 222, 293,  13, 189, 211,  10,  48,  91,  17,
#         88, 236, 217, 191,  94,  26,  53,  81, 206,  62, 225, 273, 258,
#         25, 247, 200, 254, 285, 158, 272, 260, 274,  41,  29, 213, 262,
#         90,   4,  98,  63, 130, 184, 235,  93,  27, 140, 252, 123, 286,
#        172, 103, 193, 112, 101, 226, 106,  73, 183, 296, 116, 281, 261,
#         46, 196, 244,  60,  36,  42, 251, 120,  75, 218, 122, 289,  47,
#        110, 238,  14, 179, 190, 188,  70, 187, 295,  76, 276, 264, 202,
#         65, 198,  22, 294, 282, 153, 253, 159, 234, 107,  77,   1, 117,
#         49, 243, 277, 284,  15,  23, 288,  64,  16,  68, 134,  85,  79,
#        185,  71, 216, 142, 132,   7,  66, 138, 181, 152, 155,  69, 115,
#         59, 232, 268,  24, 241, 267,  50,  57, 250, 256, 161, 141, 279,
#        219, 292,  31,  67, 237, 214, 104, 278,  55,  89,  38, 208, 145,
#        271, 133,  97,   5, 221, 169,  74, 174,   0,  86, 144, 229, 270,
#        194, 178, 199, 290, 257, 121, 137, 242, 164,  44, 176,  40,  96,
#         12,  56, 118,  78, 156,  58, 207, 283, 135, 105, 129,  39,  30,
#        114, 173,  21, 170,  99,  61,  43, 240,  80, 151, 146,   2, 205,
#        245, 166, 149, 177,  45,  82, 102,   3, 266, 231, 246, 160, 127,
#        192, 131, 182, 154, 157, 291, 204, 136,  33,  52,   8,  32,  37,
#        223, 269, 109, 212, 220, 125, 227, 224,   6, 111, 197, 171, 108,
#        287, 148, 265,  95,  83, 275,  11,  92,  28, 180, 100])

# %%
train_end = int(0.7 * count_samples)
val_end = int(0.9 * count_samples)

x_train, x_val, x_test = numpy.split(x_array, [train_end, val_end])
y_train, y_val, y_test = numpy.split(y_array, [train_end, val_end])

print('X_train shape:', x_train.shape)
print('X_val shape:', x_val.shape)
print('X_test shape:', x_test.shape)

print('Y_train shape:', y_train.shape)
print('Y_val shape:', y_val.shape)
print('Y_test shape:', y_test.shape)
# Out:
# X_train shape: (207, 18)
# X_val shape: (60, 18)
# X_test shape: (30, 18)
# Y_train shape: (207,)
# Y_val shape: (60,)
# Y_test shape: (30,)

# %%
FUNDAMENTAL_FIELDS = [
    'market_capitalization', # Рыночная капитализация
    'high_price_last_52_weeks', # Максимум за год
    'low_price_last_52_weeks', # Минимум за год
    'average_daily_volume_last_10_days', # Средний объем торгов за 10 дней
    'average_daily_volume_last_4_weeks', # Средний объем торгов за месяц
    'beta', # Нормализованная волатильность
    'shares_outstanding', # Количество акций в обращении
    'price_to_book_ttm', # Соотношение рыночной капитализации компании к ее балансовой стоимости
    'total_enterprise_value_mrq', # Рыночная стоимость компании
    'total_debt_to_equity_mrq', # Соотношение долга к собственному капиталу
    'total_debt_to_ebitda_mrq', # Total Debt/EBITDA
    'ebitda_ttm', # EBITDA
    'revenue_ttm',
    'total_debt_mrq',
    'eps_ttm',
    'pe_ratio_ttm',
    'ev_to_ebitda_mrq',
    'dividend_payout_ratio_fy',
]

def get_feature_names():
    return FUNDAMENTAL_FIELDS

# %%
import catboost

text_features = []
cat_features = []

train_pool = catboost.Pool(
    data=x_train,
    label=y_train,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)
validate_pool = catboost.Pool(
    data=x_val,
    label=y_val,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)
test_pool = catboost.Pool(
    data=x_test,
    label=y_test,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)

test_pool.shape
# Out:
# (30, 18)

# %% [markdown]
# # Обучение

# %%
model_0 = catboost.CatBoostRegressor(
    task_type='CPU',
    iterations=1_000,
    learning_rate=0.01,
    random_seed=42,
    verbose=100,
    early_stopping_rounds=200,
    eval_metric='RMSE',
    loss_function='RMSE',
    nan_mode='Min',
    use_best_model=True,
)

model_0.fit(
    train_pool,
    eval_set=validate_pool,
    plot=False,
)
# Out:
# 0:	learn: 0.1599230	test: 0.1342299	best: 0.1342299 (0)	total: 1.77ms	remaining: 1.77s
# 100:	learn: 0.1184665	test: 0.1115645	best: 0.1115645 (100)	total: 30.9ms	remaining: 275ms
# 200:	learn: 0.0933579	test: 0.0954949	best: 0.0954949 (200)	total: 58ms	remaining: 230ms
# 300:	learn: 0.0779980	test: 0.0854083	best: 0.0854083 (300)	total: 84.2ms	remaining: 195ms
# 400:	learn: 0.0681791	test: 0.0791796	best: 0.0791796 (400)	total: 110ms	remaining: 164ms
# 500:	learn: 0.0621882	test: 0.0755580	best: 0.0755580 (500)	total: 134ms	remaining: 134ms
# 600:	learn: 0.0584930	test: 0.0731410	best: 0.0731410 (600)	total: 159ms	remaining: 106ms
# 700:	learn: 0.0561325	test: 0.0718823	best: 0.0718823 (700)	total: 188ms	remaining: 80.2ms
# 800:	learn: 0.0544443	test: 0.0710531	best: 0.0710531 (800)	total: 214ms	remaining: 53.2ms
# 900:	learn: 0.0532046	test: 0.0706189	best: 0.0706189 (900)	total: 239ms	remaining: 26.2ms
# 999:	learn: 0.0524475	test: 0.0704251	best: 0.0704212 (995)	total: 263ms	remaining: 0us
#
# bestTest = 0.07042117154
# bestIteration = 995
#
# Shrink model to first 996 iterations.

# %%
import matplotlib.pyplot as plt

plt.plot(model_0.get_evals_result()['validation']['RMSE'])
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.show()

# %%
model_0_file_path = './ta-3_fundamental.cbm'
model_0.save_model(model_0_file_path)

import os

f"{os.path.getsize(model_0_file_path) / 1024 ** 2:.2f} MB"
# Out:
# '1.08 MB'

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, model_0.predict(test_pool))

mse
# Out:
# 0.010929768067139304

# %%
import numpy as np

rmse = np.sqrt(mse)

rmse
# Out:
# 0.10454553107206115

# %% [markdown]
# ## Метрики для каждой выборки

# %%
rmse_learn = model_0.get_evals_result()['learn']['RMSE']

sum(rmse_learn) / len(rmse_learn)
# Out:
# 0.07446325145868914

# %%
rmse_val = model_0.get_evals_result()['validation']['RMSE']

sum(rmse_val) / len(rmse_val)
# Out:
# 0.08337660133896944

# %%
rmse_test = model_0.eval_metrics(
    test_pool,
    metrics=['RMSE']
)['RMSE']

sum(rmse_test) / len(rmse_test)
# Out:
# 0.10439171612594646
