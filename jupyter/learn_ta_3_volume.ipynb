# %% [markdown]
# # Анализ датасета

# %%
import os
dataset_file_name = 'data_frame_ta_3_volume_2026-03-02_12-14-06.csv'
dataset_file_path = os.path.abspath(f'./{dataset_file_name}')
print(dataset_file_path)
# Out:
# /Users/artem/PycharmProjects/ticker-analysis/jupyter/data_frame_ta_3_volume_2026-03-02_12-14-06.csv

# %%
import pandas

df = pandas.read_csv(dataset_file_path)

df
# Out:
#       volume_norm_0  rsi_norm_0  volume_norm_1  rsi_norm_1  volume_norm_2  \
# 0          0.000000    0.310539      -0.055794    0.283646      -0.095925
# 1         -0.055794    0.283646      -0.095925    0.310205      -0.127278
# 2         -0.095925    0.310205      -0.127278    0.274846      -0.156622
# 3         -0.127278    0.274846      -0.156622    0.274613      -0.175619
# 4         -0.127278    0.274846      -0.156622    0.274613      -0.175619
# ...             ...         ...            ...         ...            ...
# 6585      -0.032647    0.714569      -0.104943    0.723283      -0.077686
# 6586      -0.104680    0.723283      -0.076431    0.750165      -0.021075
# 6587      -0.076431    0.750165      -0.021075    0.776182       0.081368
# 6588      -0.023055    0.776182       0.076131    0.763341       0.047769
# 6589      -0.016543    0.763341      -0.012224    0.795521      -0.015978
#
#       rsi_norm_2  volume_norm_3  rsi_norm_3  volume_norm_4  rsi_norm_4  ...  \
# 0       0.310205      -0.127278    0.274846      -0.156622    0.274613  ...
# 1       0.274846      -0.156622    0.274613      -0.175619    0.283748  ...
# 2       0.274613      -0.175619    0.283748      -0.172053    0.224922  ...
# 3       0.283748      -0.172053    0.224922      -0.153854    0.231909  ...
# 4       0.283748      -0.172053    0.224922      -0.153854    0.231909  ...
# ...          ...            ...         ...            ...         ...  ...
# 6585    0.750165      -0.023125    0.776182       0.077761    0.763341  ...
# 6586    0.776182       0.081368    0.763341       0.056724    0.795521  ...
# 6587    0.763341       0.056724    0.795521       0.025204    0.802611  ...
# 6588    0.795521       0.013834    0.802611      -0.066834    0.808550  ...
# 6589    0.802611      -0.059611    0.808550      -0.084912    0.821809  ...
#
#       rsi_norm_15  volume_norm_16  rsi_norm_16  volume_norm_17  rsi_norm_17  \
# 0        0.255643       -0.098911     0.263649       -0.107072     0.279580
# 1        0.263649       -0.107072     0.279580       -0.082140     0.328040
# 2        0.279580       -0.082140     0.328040       -0.061846     0.414215
# 3        0.328040       -0.061846     0.414215       -0.049663     0.446638
# 4        0.328040       -0.061846     0.414215       -0.049663     0.446638
# ...           ...             ...          ...             ...          ...
# 6585     0.522481       -0.013362     0.561462       -0.041091     0.626487
# 6586     0.561462       -0.035365     0.626487       -0.053516     0.602207
# 6587     0.626487       -0.053516     0.602207       -0.065992     0.501422
# 6588     0.602207       -0.075009     0.501422       -0.110665     0.535930
# 6589     0.501422       -0.035919     0.535930       -0.086546     0.528623
#
#       volume_norm_18  rsi_norm_18  volume_norm_19  rsi_norm_19  result
# 0          -0.082140     0.328040       -0.061846     0.414215   upper
# 1          -0.061846     0.414215       -0.049663     0.446638    same
# 2          -0.049663     0.446638        0.010464     0.580231    same
# 3           0.010464     0.580231        0.024502     0.611325    same
# 4           0.010464     0.580231        0.024502     0.611325   upper
# ...              ...          ...             ...          ...     ...
# 6585       -0.058761     0.602207       -0.070771     0.501422   lower
# 6586       -0.065992     0.501422       -0.102473     0.535930   lower
# 6587       -0.102473     0.535930       -0.152804     0.528623   lower
# 6588       -0.160276     0.528623       -0.192227     0.544390   lower
# 6589       -0.120692     0.544390       -0.092826     0.587606   lower
#
# [6590 rows x 41 columns]

# %%
df['result'].hist()
# Out:
# <Axes: >

# %%
df.isna().mean().sort_values(ascending=False).head(15)
# Out:
# volume_norm_0     0.0
# rsi_norm_10       0.0
# rsi_norm_11       0.0
# volume_norm_12    0.0
# rsi_norm_12       0.0
# volume_norm_13    0.0
# rsi_norm_13       0.0
# volume_norm_14    0.0
# rsi_norm_14       0.0
# volume_norm_15    0.0
# rsi_norm_15       0.0
# volume_norm_16    0.0
# rsi_norm_16       0.0
# volume_norm_17    0.0
# rsi_norm_17       0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6590 entries, 0 to 6589
# Data columns (total 41 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   volume_norm_0   6590 non-null   float64
#  1   rsi_norm_0      6590 non-null   float64
#  2   volume_norm_1   6590 non-null   float64
#  3   rsi_norm_1      6590 non-null   float64
#  4   volume_norm_2   6590 non-null   float64
#  5   rsi_norm_2      6590 non-null   float64
#  6   volume_norm_3   6590 non-null   float64
#  7   rsi_norm_3      6590 non-null   float64
#  8   volume_norm_4   6590 non-null   float64
#  9   rsi_norm_4      6590 non-null   float64
#  10  volume_norm_5   6590 non-null   float64
#  11  rsi_norm_5      6590 non-null   float64
#  12  volume_norm_6   6590 non-null   float64
#  13  rsi_norm_6      6590 non-null   float64
#  14  volume_norm_7   6590 non-null   float64
#  15  rsi_norm_7      6590 non-null   float64
#  16  volume_norm_8   6590 non-null   float64
#  17  rsi_norm_8      6590 non-null   float64
#  18  volume_norm_9   6590 non-null   float64
#  19  rsi_norm_9      6590 non-null   float64
#  20  volume_norm_10  6590 non-null   float64
#  21  rsi_norm_10     6590 non-null   float64
#  22  volume_norm_11  6590 non-null   float64
#  23  rsi_norm_11     6590 non-null   float64
#  24  volume_norm_12  6590 non-null   float64
#  25  rsi_norm_12     6590 non-null   float64
#  26  volume_norm_13  6590 non-null   float64
#  27  rsi_norm_13     6590 non-null   float64
#  28  volume_norm_14  6590 non-null   float64
#  29  rsi_norm_14     6590 non-null   float64
#  30  volume_norm_15  6590 non-null   float64
#  31  rsi_norm_15     6590 non-null   float64
#  32  volume_norm_16  6590 non-null   float64
#  33  rsi_norm_16     6590 non-null   float64
#  34  volume_norm_17  6590 non-null   float64
#  35  rsi_norm_17     6590 non-null   float64
#  36  volume_norm_18  6590 non-null   float64
#  37  rsi_norm_18     6590 non-null   float64
#  38  volume_norm_19  6590 non-null   float64
#  39  rsi_norm_19     6590 non-null   float64
#  40  result          6590 non-null   object
# dtypes: float64(40), object(1)
# memory usage: 2.1+ MB

# %%
df.describe(include='all')
# Out:
#         volume_norm_0   rsi_norm_0  volume_norm_1   rsi_norm_1  volume_norm_2  \
# count     6590.000000  6590.000000    6590.000000  6590.000000    6590.000000
# unique            NaN          NaN            NaN          NaN            NaN
# top               NaN          NaN            NaN          NaN            NaN
# freq              NaN          NaN            NaN          NaN            NaN
# mean         0.025751     0.520545       0.015381     0.518824       0.003916
# std          0.130352     0.110238       0.119371     0.108935       0.111227
# min         -0.176588     0.143954      -0.175966     0.143954      -0.195278
# 25%         -0.063585     0.441805      -0.067846     0.442435      -0.076499
# 50%         -0.006029     0.518136      -0.013022     0.516067      -0.020531
# 75%          0.074144     0.596585       0.066430     0.590954       0.058564
# max          0.668472     0.939882       0.655137     0.939882       0.655137
#
#          rsi_norm_2  volume_norm_3   rsi_norm_3  volume_norm_4   rsi_norm_4  \
# count   6590.000000    6590.000000  6590.000000    6590.000000  6590.000000
# unique          NaN            NaN          NaN            NaN          NaN
# top             NaN            NaN          NaN            NaN          NaN
# freq            NaN            NaN          NaN            NaN          NaN
# mean       0.521363      -0.004600     0.521782      -0.008169     0.524770
# std        0.109825       0.104823     0.111219       0.100027     0.110803
# min        0.143954      -0.221406     0.143954      -0.242854     0.143954
# 25%        0.444163      -0.080614     0.442559      -0.075659     0.446579
# 50%        0.519341      -0.024006     0.520110      -0.024430     0.524289
# 75%        0.593897       0.051162     0.594604       0.043563     0.596792
# max        0.939882       0.633618     0.939882       0.654654     0.939882
#
#         ...  rsi_norm_15  volume_norm_16  rsi_norm_16  volume_norm_17  \
# count   ...  6590.000000     6590.000000  6590.000000     6590.000000
# unique  ...          NaN             NaN          NaN             NaN
# top     ...          NaN             NaN          NaN             NaN
# freq    ...          NaN             NaN          NaN             NaN
# mean    ...     0.537755       -0.015333     0.538034       -0.015337
# std     ...     0.109470        0.103332     0.109035        0.110243
# min     ...     0.143954       -0.259877     0.143954       -0.256325
# 25%     ...     0.466883       -0.084732     0.467641       -0.090691
# 50%     ...     0.537471       -0.030105     0.537048       -0.028946
# 75%     ...     0.606410        0.034980     0.605827        0.039648
# max     ...     0.939882        0.714178     0.939882        0.629168
#
#         rsi_norm_17  volume_norm_18  rsi_norm_18  volume_norm_19  rsi_norm_19  \
# count   6590.000000     6590.000000  6590.000000     6590.000000  6590.000000
# unique          NaN             NaN          NaN             NaN          NaN
# top             NaN             NaN          NaN             NaN          NaN
# freq            NaN             NaN          NaN             NaN          NaN
# mean       0.538819       -0.008334     0.537188       -0.008080     0.537736
# std        0.108846        0.109140     0.110001        0.104349     0.110637
# min        0.143954       -0.256060     0.143954       -0.258316     0.143954
# 25%        0.469310       -0.080868     0.464968       -0.076847     0.463980
# 50%        0.538546       -0.021229     0.537209       -0.023394     0.538612
# 75%        0.605564        0.045652     0.606568        0.042483     0.608242
# max        0.939882        0.678495     0.939882        0.637713     0.939882
#
#         result
# count     6590
# unique       3
# top       same
# freq      3800
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
#
# [11 rows x 41 columns]

# %%
df['result'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Подготовка данных для обучения

# %%
df_learn = df # df.copy()

x = df_learn.drop(columns=['result'])
y = df_learn['result']

x
# Out:
#       volume_norm_0  rsi_norm_0  volume_norm_1  rsi_norm_1  volume_norm_2  \
# 0          0.000000    0.310539      -0.055794    0.283646      -0.095925
# 1         -0.055794    0.283646      -0.095925    0.310205      -0.127278
# 2         -0.095925    0.310205      -0.127278    0.274846      -0.156622
# 3         -0.127278    0.274846      -0.156622    0.274613      -0.175619
# 4         -0.127278    0.274846      -0.156622    0.274613      -0.175619
# ...             ...         ...            ...         ...            ...
# 6585      -0.032647    0.714569      -0.104943    0.723283      -0.077686
# 6586      -0.104680    0.723283      -0.076431    0.750165      -0.021075
# 6587      -0.076431    0.750165      -0.021075    0.776182       0.081368
# 6588      -0.023055    0.776182       0.076131    0.763341       0.047769
# 6589      -0.016543    0.763341      -0.012224    0.795521      -0.015978
#
#       rsi_norm_2  volume_norm_3  rsi_norm_3  volume_norm_4  rsi_norm_4  ...  \
# 0       0.310205      -0.127278    0.274846      -0.156622    0.274613  ...
# 1       0.274846      -0.156622    0.274613      -0.175619    0.283748  ...
# 2       0.274613      -0.175619    0.283748      -0.172053    0.224922  ...
# 3       0.283748      -0.172053    0.224922      -0.153854    0.231909  ...
# 4       0.283748      -0.172053    0.224922      -0.153854    0.231909  ...
# ...          ...            ...         ...            ...         ...  ...
# 6585    0.750165      -0.023125    0.776182       0.077761    0.763341  ...
# 6586    0.776182       0.081368    0.763341       0.056724    0.795521  ...
# 6587    0.763341       0.056724    0.795521       0.025204    0.802611  ...
# 6588    0.795521       0.013834    0.802611      -0.066834    0.808550  ...
# 6589    0.802611      -0.059611    0.808550      -0.084912    0.821809  ...
#
#       volume_norm_15  rsi_norm_15  volume_norm_16  rsi_norm_16  \
# 0          -0.084271     0.255643       -0.098911     0.263649
# 1          -0.098911     0.263649       -0.107072     0.279580
# 2          -0.107072     0.279580       -0.082140     0.328040
# 3          -0.082140     0.328040       -0.061846     0.414215
# 4          -0.082140     0.328040       -0.061846     0.414215
# ...              ...          ...             ...          ...
# 6585       -0.079260     0.522481       -0.013362     0.561462
# 6586       -0.007156     0.561462       -0.035365     0.626487
# 6587       -0.035365     0.626487       -0.053516     0.602207
# 6588       -0.063406     0.602207       -0.075009     0.501422
# 6589        0.001317     0.501422       -0.035919     0.535930
#
#       volume_norm_17  rsi_norm_17  volume_norm_18  rsi_norm_18  \
# 0          -0.107072     0.279580       -0.082140     0.328040
# 1          -0.082140     0.328040       -0.061846     0.414215
# 2          -0.061846     0.414215       -0.049663     0.446638
# 3          -0.049663     0.446638        0.010464     0.580231
# 4          -0.049663     0.446638        0.010464     0.580231
# ...              ...          ...             ...          ...
# 6585       -0.041091     0.626487       -0.058761     0.602207
# 6586       -0.053516     0.602207       -0.065992     0.501422
# 6587       -0.065992     0.501422       -0.102473     0.535930
# 6588       -0.110665     0.535930       -0.160276     0.528623
# 6589       -0.086546     0.528623       -0.120692     0.544390
#
#       volume_norm_19  rsi_norm_19
# 0          -0.061846     0.414215
# 1          -0.049663     0.446638
# 2           0.010464     0.580231
# 3           0.024502     0.611325
# 4           0.024502     0.611325
# ...              ...          ...
# 6585       -0.070771     0.501422
# 6586       -0.102473     0.535930
# 6587       -0.152804     0.528623
# 6588       -0.192227     0.544390
# 6589       -0.092826     0.587606
#
# [6590 rows x 40 columns]

# %%
import numpy

x_array = x.values
y_array = y.values
count_samples = len(x_array)

random_indexes = numpy.random.permutation(count_samples)

x_array = x_array[random_indexes]
y_array = y_array[random_indexes]

random_indexes
# Out:
# array([6040,   22,   70, ..., 1778, 1753, 4636])

# %%
train_end = int(0.7 * count_samples)
val_end = int(0.85 * count_samples)

x_train, x_val, x_test = numpy.split(x_array, [train_end, val_end])
y_train, y_val, y_test = numpy.split(y_array, [train_end, val_end])

print('X_train shape:', x_train.shape)
print('X_val shape:', x_val.shape)
print('X_test shape:', x_test.shape)

print('Y_train shape:', y_train.shape)
print('Y_val shape:', y_val.shape)
print('Y_test shape:', y_test.shape)
# Out:
# X_train shape: (4613, 40)
# X_val shape: (988, 40)
# X_test shape: (989, 40)
# Y_train shape: (4613,)
# Y_val shape: (988,)
# Y_test shape: (989,)

# %%
def get_feature_names() -> list:
    feature_names = []

    for i in range(20):
        feature_names.extend([
            f'volume_norm_{i}',
            f'rsi_norm_{i}',
        ])

    return feature_names

# %%
import catboost

text_features = []
cat_features = []

train_pool = catboost.Pool(
    data=x_train,
    label=y_train,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)
validate_pool = catboost.Pool(
    data=x_val,
    label=y_val,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)
test_pool = catboost.Pool(
    data=x_test,
    label=y_test,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)

print('TRAIN POOL', train_pool.shape)
print('VALIDATION POOL', validate_pool.shape)
print('TEST POOL', test_pool.shape)
# Out:
# TRAIN POOL (4613, 40)
# VALIDATION POOL (988, 40)
# TEST POOL (989, 40)

# %% [markdown]
# # Поиск оптимальных параметров обучения

# %%
regressor_params = {
    'task_type': 'CPU',
    'random_seed': 42,
    'verbose': 100,
    'early_stopping_rounds': 200,
    'nan_mode': 'Min',
    'use_best_model': True,
}

# %%
import os
import optuna
from optuna.storages import RDBStorage
from sklearn.metrics import mean_squared_error

def objective(trial):
    iterations = trial.suggest_int('iterations', 100, 10_000, step=100)
    learning_rate = trial.suggest_float('learning_rate', 0.01, 0.9, step=0.001)
    depth = trial.suggest_int('depth', 3, 10, step=1)
    l2_leaf_reg = trial.suggest_int('l2_leaf_reg', 1, 10, step=1)

    params = regressor_params
    params.update(
        iterations=iterations,
        learning_rate=learning_rate,
        depth=depth,
        l2_leaf_reg=l2_leaf_reg,
        verbose=False,
    )

    trial_model = catboost.CatBoostRegressor(**params)
    
    trial_model.fit(
        train_pool,
        eval_set=validate_pool,
        plot=False,
    )
    
    return mean_squared_error(y_test, trial_model.predict(test_pool))


db_path = os.path.abspath('./db.sqlite3')
storage = RDBStorage(f'sqlite:///{db_path}')
study = optuna.create_study(storage=storage)
study.optimize(objective, n_trials=30)

study.best_params
# Out:
# [I 2026-02-13 13:52:36,521] A new study created in RDB with name: no-name-d2c77f01-70b2-433d-ab1a-7ff615bcfc03

# %% [markdown]
# # Обучение

# %%
params = regressor_params
params.update(
    iterations=10_000, #study.best_params.get('iterations', 5_000),
    learning_rate=0.01, #study.best_params.get('learning_rate', 0.27),
)

model_0 = catboost.CatBoostClassifier(**params)

model_0.fit(
    train_pool,
    eval_set=validate_pool,
    plot=False,
)
# Out:
# 0:	learn: 1.0953817	test: 1.0955938	best: 1.0955938 (0)	total: 18.2ms	remaining: 3m 1s
# 100:	learn: 0.9322743	test: 0.9557101	best: 0.9557101 (100)	total: 754ms	remaining: 1m 13s
# 200:	learn: 0.8812338	test: 0.9206953	best: 0.9206953 (200)	total: 1.49s	remaining: 1m 12s
# 300:	learn: 0.8524305	test: 0.9044175	best: 0.9044175 (300)	total: 2.21s	remaining: 1m 11s
# 400:	learn: 0.8317258	test: 0.8945813	best: 0.8945813 (400)	total: 2.9s	remaining: 1m 9s
# 500:	learn: 0.8134090	test: 0.8865407	best: 0.8865407 (500)	total: 3.93s	remaining: 1m 14s
# 600:	learn: 0.7958630	test: 0.8795018	best: 0.8795018 (600)	total: 4.74s	remaining: 1m 14s
# 700:	learn: 0.7806102	test: 0.8737631	best: 0.8737631 (700)	total: 5.5s	remaining: 1m 12s
# 800:	learn: 0.7651710	test: 0.8681687	best: 0.8681687 (800)	total: 6.23s	remaining: 1m 11s
# 900:	learn: 0.7502940	test: 0.8622324	best: 0.8622324 (900)	total: 6.93s	remaining: 1m 10s
# 1000:	learn: 0.7357142	test: 0.8571731	best: 0.8571731 (1000)	total: 7.63s	remaining: 1m 8s
# 1100:	learn: 0.7211555	test: 0.8526029	best: 0.8526029 (1100)	total: 8.33s	remaining: 1m 7s
# 1200:	learn: 0.7062418	test: 0.8482573	best: 0.8482573 (1200)	total: 9.03s	remaining: 1m 6s
# 1300:	learn: 0.6922172	test: 0.8447643	best: 0.8447643 (1300)	total: 9.73s	remaining: 1m 5s
# 1400:	learn: 0.6786467	test: 0.8410479	best: 0.8410479 (1400)	total: 10.4s	remaining: 1m 4s
# 1500:	learn: 0.6655986	test: 0.8379521	best: 0.8379521 (1500)	total: 11.1s	remaining: 1m 3s
# 1600:	learn: 0.6536398	test: 0.8349978	best: 0.8349978 (1600)	total: 11.9s	remaining: 1m 2s
# 1700:	learn: 0.6420061	test: 0.8318776	best: 0.8318776 (1700)	total: 12.6s	remaining: 1m 1s
# 1800:	learn: 0.6302751	test: 0.8294198	best: 0.8294097 (1798)	total: 13.3s	remaining: 1m
# 1900:	learn: 0.6191118	test: 0.8269545	best: 0.8269545 (1900)	total: 14s	remaining: 59.5s
# 2000:	learn: 0.6079830	test: 0.8250836	best: 0.8250530 (1999)	total: 14.7s	remaining: 58.6s
# 2100:	learn: 0.5970918	test: 0.8231851	best: 0.8231819 (2099)	total: 15.4s	remaining: 57.8s
# 2200:	learn: 0.5866029	test: 0.8215341	best: 0.8215341 (2200)	total: 16.1s	remaining: 57.1s
# 2300:	learn: 0.5767786	test: 0.8193386	best: 0.8193386 (2300)	total: 16.8s	remaining: 56.4s
# 2400:	learn: 0.5674177	test: 0.8179460	best: 0.8179249 (2399)	total: 17.6s	remaining: 55.7s
# 2500:	learn: 0.5581287	test: 0.8166432	best: 0.8166265 (2499)	total: 18.3s	remaining: 54.9s
# 2600:	learn: 0.5488355	test: 0.8151466	best: 0.8151466 (2600)	total: 19.1s	remaining: 54.2s
# 2700:	learn: 0.5396956	test: 0.8134622	best: 0.8134425 (2697)	total: 19.8s	remaining: 53.5s
# 2800:	learn: 0.5305383	test: 0.8124462	best: 0.8124274 (2799)	total: 20.6s	remaining: 52.9s
# 2900:	learn: 0.5218681	test: 0.8114983	best: 0.8114983 (2900)	total: 21.3s	remaining: 52.1s
# 3000:	learn: 0.5132277	test: 0.8104910	best: 0.8104335 (2980)	total: 22s	remaining: 51.4s
# 3100:	learn: 0.5049005	test: 0.8094581	best: 0.8094207 (3066)	total: 22.8s	remaining: 50.6s
# 3200:	learn: 0.4969713	test: 0.8084562	best: 0.8084562 (3200)	total: 23.5s	remaining: 49.9s
# 3300:	learn: 0.4894029	test: 0.8071415	best: 0.8071268 (3299)	total: 24.3s	remaining: 49.2s
# 3400:	learn: 0.4817796	test: 0.8063363	best: 0.8062652 (3395)	total: 25s	remaining: 48.5s
# 3500:	learn: 0.4745911	test: 0.8055314	best: 0.8054803 (3497)	total: 25.7s	remaining: 47.8s
# 3600:	learn: 0.4675576	test: 0.8044408	best: 0.8044408 (3600)	total: 26.4s	remaining: 47s
# 3700:	learn: 0.4604873	test: 0.8035907	best: 0.8035532 (3698)	total: 27.1s	remaining: 46.2s
# 3800:	learn: 0.4533922	test: 0.8024241	best: 0.8024072 (3798)	total: 27.9s	remaining: 45.4s
# 3900:	learn: 0.4462775	test: 0.8022315	best: 0.8021759 (3873)	total: 28.6s	remaining: 44.8s
# 4000:	learn: 0.4396954	test: 0.8014830	best: 0.8014830 (4000)	total: 29.4s	remaining: 44s
# 4100:	learn: 0.4330332	test: 0.8008150	best: 0.8008064 (4098)	total: 30.1s	remaining: 43.3s
# 4200:	learn: 0.4266584	test: 0.8001362	best: 0.8001096 (4199)	total: 30.8s	remaining: 42.5s
# 4300:	learn: 0.4199215	test: 0.7995373	best: 0.7995306 (4295)	total: 31.5s	remaining: 41.8s
# 4400:	learn: 0.4136732	test: 0.7993533	best: 0.7991849 (4356)	total: 32.2s	remaining: 41s
# 4500:	learn: 0.4077439	test: 0.7992691	best: 0.7991778 (4452)	total: 32.9s	remaining: 40.2s
# 4600:	learn: 0.4020575	test: 0.7988569	best: 0.7988068 (4596)	total: 33.6s	remaining: 39.5s
# 4700:	learn: 0.3963195	test: 0.7984098	best: 0.7983718 (4689)	total: 34.3s	remaining: 38.7s
# 4800:	learn: 0.3906356	test: 0.7981008	best: 0.7980840 (4794)	total: 35s	remaining: 37.9s
# 4900:	learn: 0.3854234	test: 0.7975245	best: 0.7974231 (4858)	total: 35.7s	remaining: 37.2s
# 5000:	learn: 0.3795736	test: 0.7972486	best: 0.7971760 (4986)	total: 36.5s	remaining: 36.4s
# 5100:	learn: 0.3743114	test: 0.7971142	best: 0.7970255 (5060)	total: 37.2s	remaining: 35.7s
# 5200:	learn: 0.3690323	test: 0.7964935	best: 0.7964802 (5197)	total: 37.9s	remaining: 34.9s
# 5300:	learn: 0.3638158	test: 0.7962067	best: 0.7962008 (5298)	total: 38.6s	remaining: 34.2s
# 5400:	learn: 0.3585922	test: 0.7958416	best: 0.7958090 (5399)	total: 39.3s	remaining: 33.4s
# 5500:	learn: 0.3534065	test: 0.7957705	best: 0.7956524 (5437)	total: 40s	remaining: 32.7s
# 5600:	learn: 0.3485310	test: 0.7955645	best: 0.7954767 (5593)	total: 40.7s	remaining: 32s
# 5700:	learn: 0.3436804	test: 0.7952222	best: 0.7952095 (5699)	total: 41.4s	remaining: 31.2s
# 5800:	learn: 0.3389490	test: 0.7950138	best: 0.7950018 (5796)	total: 42.1s	remaining: 30.5s
# 5900:	learn: 0.3344152	test: 0.7945157	best: 0.7944250 (5878)	total: 42.8s	remaining: 29.8s
# 6000:	learn: 0.3298746	test: 0.7946857	best: 0.7944250 (5878)	total: 43.5s	remaining: 29s
# 6100:	learn: 0.3253219	test: 0.7945231	best: 0.7943091 (6069)	total: 44.3s	remaining: 28.3s
# 6200:	learn: 0.3211257	test: 0.7944138	best: 0.7943091 (6069)	total: 45s	remaining: 27.5s
# 6300:	learn: 0.3169273	test: 0.7946146	best: 0.7942374 (6219)	total: 45.7s	remaining: 26.8s
# 6400:	learn: 0.3127609	test: 0.7946383	best: 0.7942374 (6219)	total: 46.4s	remaining: 26.1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7942373574
# bestIteration = 6219
#
# Shrink model to first 6220 iterations.

# %%
import matplotlib.pyplot as plt

plt.plot(model_0.get_evals_result()['validation']['MultiClass'])
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.show()

# %%
model_0_file_path = './ta-3_technical.cbm'
model_0.save_model(model_0_file_path)

import os

f"{os.path.getsize(model_0_file_path) / 1024 ** 2:.2f} MB"
# Out:
# '12.95 MB'

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, model_0.predict(test_pool))

acc
# Out:
# 0.6430738119312437

# %%
from sklearn.metrics import roc_auc_score

auc = roc_auc_score(y_test, model_0.predict_proba(test_pool), multi_class='ovr')

auc
# Out:
# 0.7355903171373303
