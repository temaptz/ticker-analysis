# %% [markdown]
# # Анализ датасета

# %%
import os
dataset_file_name = 'data_frame_ta_2_1_2025-10-13_01-00-03.csv'
dataset_file_path = os.path.abspath(f'./{dataset_file_name}')
print(dataset_file_path)
# Out:
# /Users/artem/PycharmProjects/ticker-analysis/jupyter/data_frame_ta_2_1_2025-10-13_01-00-03.csv

# %%
import pandas

df = pandas.read_csv(dataset_file_path)

df
# Out:
#          target_date_days               name currency country_of_risk  \
# 0                       1  Ozon Holdings PLC      rub              US
# 1                       2  Ozon Holdings PLC      rub              US
# 2                       3  Ozon Holdings PLC      rub              US
# 3                       4  Ozon Holdings PLC      rub              US
# 4                       5  Ozon Holdings PLC      rub              US
# ...                   ...                ...      ...             ...
# 1262235                 2                 ВК      rub              RU
# 1262236                 3                 ВК      rub              RU
# 1262237                 1                 ВК      rub              RU
# 1262238                 2                 ВК      rub              RU
# 1262239                 1                 ВК      rub              RU
#
#          forecast_price_change  market_volume        rsi       macd  \
# 0                     0.109325       162039.0  55.530609  94.061493
# 1                     0.109325       162039.0  55.530609  94.061493
# 2                     0.109325       162039.0  55.530609  94.061493
# 3                     0.109325       162039.0  55.530609  94.061493
# 4                     0.109325       162039.0  55.530609  94.061493
# ...                        ...            ...        ...        ...
# 1262235               0.365617      5306434.0  22.292381 -12.521291
# 1262236               0.365617      5306434.0  22.292381 -12.521291
# 1262237               0.365617      3788704.0  28.192020 -12.904563
# 1262238               0.365617      3788704.0  28.192020 -12.904563
# 1262239               0.459723      4276954.0  33.396984 -13.196301
#
#           revenue_ttm    ebitda_ttm  ...  price_change_6_month  \
# 0        6.157320e+11  4.007900e+10  ...             -0.170340
# 1        6.157320e+11  4.007900e+10  ...             -0.170340
# 2        6.157320e+11  4.007900e+10  ...             -0.170340
# 3        6.157320e+11  4.007900e+10  ...             -0.170340
# 4        6.157320e+11  4.007900e+10  ...             -0.170340
# ...               ...           ...  ...                   ...
# 1262235  1.499520e+11  6.212000e+09  ...             -0.080215
# 1262236  1.499520e+11  6.212000e+09  ...             -0.080215
# 1262237  1.499520e+11  6.212000e+09  ...             -0.066506
# 1262238  1.499520e+11  6.212000e+09  ...             -0.066506
# 1262239  1.499520e+11  6.212000e+09  ...             -0.010495
#
#          price_change_7_month  price_change_8_month  price_change_9_month  \
# 0                   -0.194630             -0.066937              0.070372
# 1                   -0.194630             -0.066937              0.070372
# 2                   -0.194630             -0.066937              0.070372
# 3                   -0.194630             -0.066937              0.070372
# 4                   -0.194630             -0.066937              0.070372
# ...                       ...                   ...                   ...
# 1262235              0.233976              0.223046              0.249722
# 1262236              0.233976              0.223046              0.249722
# 1262237              0.228233              0.223046              0.273064
# 1262238              0.228233              0.223046              0.273064
# 1262239              0.295842              0.301188              0.360792
#
#          price_change_10_month  price_change_11_month  price_change_1_year  \
# 0                     0.090790               0.087106            -0.102342
# 1                     0.090790               0.087106            -0.102342
# 2                     0.090790               0.087106            -0.102342
# 3                     0.090790               0.087106            -0.102342
# 4                     0.090790               0.087106            -0.102342
# ...                        ...                    ...                  ...
# 1262235              -0.116710               0.153761             0.254539
# 1262236              -0.116710               0.153761             0.254539
# 1262237              -0.100408               0.147462             0.268618
# 1262238              -0.100408               0.147462             0.268618
# 1262239              -0.021782               0.184158             0.388515
#
#          price_change_2_years  price_change_3_years    result
# 0                   -0.573462                   NaN  0.000187
# 1                   -0.573462                   NaN -0.009928
# 2                   -0.573462                   NaN -0.012800
# 3                   -0.573462                   NaN -0.022292
# 4                   -0.573462                   NaN -0.017796
# ...                       ...                   ...       ...
# 1262235                   NaN              0.626528 -0.064468
# 1262236                   NaN              0.626528 -0.017229
# 1262237                   NaN              0.626528 -0.064468
# 1262238                   NaN              0.626528 -0.017229
# 1262239                   NaN              0.738614  0.050495
#
# [1262240 rows x 76 columns]

# %%
df['target_date_days'].hist()
# Out:
# <Axes: >

# %%
df.isna().mean().sort_values(ascending=False).head(15)
# Out:
# forecast_price_change     0.177633
# news_influence_score_4    0.151419
# news_influence_score_3    0.143340
# news_influence_score_1    0.139146
# news_influence_score_2    0.138311
# news_influence_score_0    0.115997
# price_change_3_years      0.094238
# price_change_2_years      0.072730
# market_volume             0.058615
# price_change_9_month      0.022748
# price_change_10_month     0.021116
# price_change_11_month     0.020426
# price_change_8_month      0.018782
# price_change_7_month      0.018354
# price_change_1_year       0.015619
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1262240 entries, 0 to 1262239
# Data columns (total 76 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   target_date_days           1262240 non-null  int64
#  1   name                       1262240 non-null  object
#  2   currency                   1262240 non-null  object
#  3   country_of_risk            1262240 non-null  object
#  4   forecast_price_change      1038024 non-null  float64
#  5   market_volume              1188254 non-null  float64
#  6   rsi                        1262237 non-null  float64
#  7   macd                       1262239 non-null  float64
#  8   revenue_ttm                1262240 non-null  float64
#  9   ebitda_ttm                 1262240 non-null  float64
#  10  market_capitalization      1262240 non-null  float64
#  11  total_debt_mrq             1262240 non-null  float64
#  12  eps_ttm                    1262240 non-null  float64
#  13  pe_ratio_ttm               1262240 non-null  float64
#  14  ev_to_ebitda_mrq           1262240 non-null  float64
#  15  dividend_payout_ratio_fy   1262240 non-null  float64
#  16  news_influence_score_0     1115824 non-null  float64
#  17  news_influence_score_1     1086604 non-null  float64
#  18  news_influence_score_2     1087658 non-null  float64
#  19  news_influence_score_3     1081311 non-null  float64
#  20  news_influence_score_4     1071113 non-null  float64
#  21  price_change_2_days_min    1252544 non-null  float64
#  22  price_change_2_days_max    1253955 non-null  float64
#  23  price_change_1_week_min    1256823 non-null  float64
#  24  price_change_1_week_max    1260116 non-null  float64
#  25  price_change_2_week_min    1257407 non-null  float64
#  26  price_change_2_week_max    1260934 non-null  float64
#  27  price_change_3_week_min    1257826 non-null  float64
#  28  price_change_3_week_max    1261312 non-null  float64
#  29  price_change_1_month_min   1258163 non-null  float64
#  30  price_change_1_month_max   1261652 non-null  float64
#  31  price_change_2_month_min   1258071 non-null  float64
#  32  price_change_2_month_max   1260826 non-null  float64
#  33  price_change_3_month_min   1258983 non-null  float64
#  34  price_change_3_month_max   1261411 non-null  float64
#  35  price_change_4_month_min   1260033 non-null  float64
#  36  price_change_4_month_max   1261783 non-null  float64
#  37  price_change_5_month_min   1260318 non-null  float64
#  38  price_change_5_month_max   1261837 non-null  float64
#  39  price_change_6_month_min   1260918 non-null  float64
#  40  price_change_6_month_max   1261890 non-null  float64
#  41  price_change_7_month_min   1260837 non-null  float64
#  42  price_change_7_month_max   1261890 non-null  float64
#  43  price_change_8_month_min   1261013 non-null  float64
#  44  price_change_8_month_max   1261890 non-null  float64
#  45  price_change_9_month_min   1261013 non-null  float64
#  46  price_change_9_month_max   1261965 non-null  float64
#  47  price_change_10_month_min  1261104 non-null  float64
#  48  price_change_10_month_max  1262047 non-null  float64
#  49  price_change_11_month_min  1261580 non-null  float64
#  50  price_change_11_month_max  1262110 non-null  float64
#  51  price_change_1_year_min    1261580 non-null  float64
#  52  price_change_1_year_max    1262183 non-null  float64
#  53  price_change_2_years_min   1261580 non-null  float64
#  54  price_change_2_years_max   1262240 non-null  float64
#  55  price_change_3_years_min   1262154 non-null  float64
#  56  price_change_3_years_max   1262240 non-null  float64
#  57  price_change_2_days        1257618 non-null  float64
#  58  price_change_1_week        1257825 non-null  float64
#  59  price_change_2_week        1257973 non-null  float64
#  60  price_change_3_week        1256971 non-null  float64
#  61  price_change_1_month       1257032 non-null  float64
#  62  price_change_2_month       1255635 non-null  float64
#  63  price_change_3_month       1254182 non-null  float64
#  64  price_change_4_month       1250326 non-null  float64
#  65  price_change_5_month       1247964 non-null  float64
#  66  price_change_6_month       1245992 non-null  float64
#  67  price_change_7_month       1239073 non-null  float64
#  68  price_change_8_month       1238532 non-null  float64
#  69  price_change_9_month       1233526 non-null  float64
#  70  price_change_10_month      1235587 non-null  float64
#  71  price_change_11_month      1236458 non-null  float64
#  72  price_change_1_year        1242525 non-null  float64
#  73  price_change_2_years       1170437 non-null  float64
#  74  price_change_3_years       1143289 non-null  float64
#  75  result                     1262240 non-null  float64
# dtypes: float64(72), int64(1), object(3)
# memory usage: 731.9+ MB

# %%
df.describe()
# Out:
#        target_date_days  forecast_price_change  market_volume           rsi  \
# count      1.262240e+06           1.038024e+06   1.188254e+06  1.262237e+06
# mean       6.885043e+01           3.021066e-01   2.945338e+06  4.477395e+01
# std        4.828664e+01           2.540912e-01   1.435354e+07  2.253729e+01
# min        1.000000e+00          -4.054157e-01   3.000000e+00  9.480114e-02
# 25%        2.800000e+01           1.631861e-01   4.217100e+04  2.621742e+01
# 50%        6.100000e+01           2.934762e-01   2.807540e+05  4.441822e+01
# 75%        1.030000e+02           4.255226e-01   1.295649e+06  6.205927e+01
# max        2.040000e+02           1.667683e+00   6.311718e+08  9.930922e+01
#
#                macd   revenue_ttm    ebitda_ttm  market_capitalization  \
# count  1.262239e+06  1.262240e+06  1.262240e+06           1.262240e+06
# mean  -1.084559e+01  1.306410e+12  1.965494e+11           6.404905e+11
# std    1.616550e+02  2.473643e+12  5.392692e+11           1.263057e+12
# min   -1.263386e+03 -2.666033e+10 -8.830285e+09           0.000000e+00
# 25%   -5.217520e+00  7.588300e+10  0.000000e+00           4.170905e+10
# 50%   -6.819379e-01  3.874770e+11  1.865800e+10           1.631183e+11
# 75%    6.337220e-02  1.118264e+12  1.021020e+11           4.675650e+11
# max    2.153344e+03  1.074451e+13  3.195875e+12           6.982082e+12
#
#        total_debt_mrq       eps_ttm  ...  price_change_6_month  \
# count    1.262240e+06  1.262240e+06  ...          1.245992e+06
# mean     2.983456e+11  1.621786e+02  ...          2.913215e-02
# std      8.253638e+11  4.641174e+02  ...          1.694218e-01
# min      0.000000e+00 -1.141240e+03  ...         -4.155310e-01
# 25%      3.827616e+09  0.000000e+00  ...         -9.679257e-02
# 50%      7.158600e+10  1.140000e+01  ...          2.526067e-02
# 75%      2.600000e+11  1.265300e+02  ...          1.372056e-01
# max      6.714810e+12  2.158970e+03  ...          1.438395e+00
#
#        price_change_7_month  price_change_8_month  price_change_9_month  \
# count          1.239073e+06          1.238532e+06          1.233526e+06
# mean           2.748339e-02          8.876192e-02          1.781769e-01
# std            1.750271e-01          5.194373e-01          7.849458e-01
# min           -4.331352e-01         -4.353244e-01         -4.252076e-01
# 25%           -1.065784e-01         -8.728652e-02         -5.963614e-02
# 50%            2.149313e-02          5.648975e-02          1.051062e-01
# 75%            1.409619e-01          1.893964e-01          2.571108e-01
# max            1.925998e+00          8.552938e+00          1.012180e+01
#
#        price_change_10_month  price_change_11_month  price_change_1_year  \
# count           1.235587e+06           1.236458e+06         1.242525e+06
# mean            2.937359e-01           4.217216e-01         5.486264e-01
# std             1.001267e+00           1.174825e+00         1.325659e+00
# min            -4.008155e-01          -3.626262e-01        -4.643731e-01
# 25%            -1.333996e-02           4.224409e-02         1.019274e-01
# 50%             1.738095e-01           2.615240e-01         3.403895e-01
# 75%             3.682793e-01           4.930748e-01         6.354675e-01
# max             1.064231e+01           1.150441e+01         1.237033e+01
#
#        price_change_2_years  price_change_3_years        result
# count          1.170437e+06          1.143289e+06  1.262240e+06
# mean           4.170785e-01          7.739099e-02 -3.966597e-02
# std            1.310448e+00          9.420519e-01  1.128621e-01
# min           -6.995628e-01         -9.032331e-01 -6.617732e-01
# 25%           -1.444472e-01         -4.576988e-01 -1.029099e-01
# 50%            1.554371e-01         -1.279757e-01 -3.207961e-02
# 75%            4.210050e-01          2.222037e-01  2.324052e-02
# max            1.397118e+01          6.337610e+00  5.657396e-01
#
# [8 rows x 73 columns]

# %%
df['result'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Отсечение резких скачков

# %%
df['price_change_7_month'].hist()
# Out:
# <Axes: >

# %%
df['price_change_7_month'].hist()
df['price_change_8_month'].hist()
df['price_change_9_month'].hist()
df['price_change_10_month'].hist()
df['price_change_11_month'].hist()
df['price_change_1_year'].hist()
df['price_change_2_years'].hist()
df['price_change_3_years'].hist()
# Out:
# <Axes: >

# %%
q1 = df['price_change_7_month'].quantile(.99999)
q2 = df['price_change_8_month'].quantile(.996)
q3 = df['price_change_9_month'].quantile(.992)
q4 = df['price_change_10_month'].quantile(.989)
q5 = df['price_change_11_month'].quantile(.987)
q6 = df['price_change_1_year'].quantile(.985)
q7 = df['price_change_2_years'].quantile(.983)
q8 = df['price_change_3_years'].quantile(.99999)
q8
# Out:
# 6.10242223739624

# %%
df[df['price_change_7_month'] < q1]['price_change_7_month'].hist()
df[df['price_change_8_month'] < q2]['price_change_8_month'].hist()
df[df['price_change_9_month'] < q3]['price_change_9_month'].hist()
df[df['price_change_10_month'] < q4]['price_change_10_month'].hist()
df[df['price_change_11_month'] < q5]['price_change_11_month'].hist()
df[df['price_change_1_year'] < q6]['price_change_1_year'].hist()
df[df['price_change_2_years'] < q7]['price_change_2_years'].hist()
df[df['price_change_3_years'] < q8]['price_change_3_years'].hist()
# Out:
# <Axes: >

# %%
df_history_smooth = df[
    (df['price_change_7_month'] < q1) 
    & (df['price_change_8_month'] < q2)
    & (df['price_change_9_month'] < q3)
    & (df['price_change_10_month'] < q4)
    & (df['price_change_11_month'] < q5)
    & (df['price_change_1_year'] < q6)
    & (df['price_change_2_years'] < q7)
    & (df['price_change_3_years'] < q8)
    ].copy()
f'filtered {df.shape[0] - df_history_smooth.shape[0]}'
# Out:
# 'filtered 194033'

# %% [markdown]
# # Анализ данных

# %%
df.groupby('name')['result'].mean().sort_values(ascending=False).head(50)
# Out:
# name
# QIWI                                        0.113827
# Циан                                        0.087448
# Ozon Holdings PLC                           0.083504
# Ростелеком - Привилегированные акции        0.068508
# Хэдхантер                                   0.048104
# ФосАгро                                     0.047985
# Ростелеком                                  0.040352
# Норильский никель                           0.039271
# Россети Ленэнерго                           0.035401
# ЕвроТранс                                   0.034348
# Акрон                                       0.003304
# Трубная Металлургическая Компания           0.002864
# АФК Система                                -0.001304
# Эн+                                        -0.002600
# Сбер Банк - привилегированные акции        -0.005459
# Сбер Банк                                  -0.006607
# НОВАТЭК                                    -0.006829
# Яндекс                                     -0.007714
# O'Key Group SA                             -0.010029
# Совкомфлот                                 -0.011084
# МТС                                        -0.015755
# ВСМПО-АВИСМА                               -0.016248
# Селигдар                                   -0.017506
# Роснефть                                   -0.028475
# Татнефть - привилегированные акции         -0.028982
# Сегежа                                     -0.029770
# Северсталь                                 -0.030606
# ДВМП                                       -0.031301
# Магнитогорский металлургический комбинат   -0.031308
# РУСАЛ                                      -0.032291
# Мосэнерго                                  -0.034800
# ЛУКОЙЛ                                     -0.036137
# Объединенная авиастроительная корпорация   -0.039138
# Газпром нефть                              -0.039807
# НМТП                                       -0.043857
# Белон                                      -0.044163
# Газпром                                    -0.050388
# Европлан                                   -0.050844
# АЛРОСА                                     -0.051212
# ГТМ                                        -0.052318
# ВК                                         -0.054121
# Совкомбанк                                 -0.055594
# Мостотрест                                 -0.058665
# РуссНефть                                  -0.060622
# Интер РАО ЕЭС                              -0.063075
# Группа Черкизово                           -0.063390
# Банк ВТБ                                   -0.067533
# НЛМК                                       -0.070461
# Русолово                                   -0.070593
# Аэрофлот                                   -0.075993
# Name: result, dtype: float64

# %% [markdown]
# # Подготовка данных для обучения

# %%
df_learn = df_history_smooth.copy()

x = df_learn.drop(columns=['result'])
y = df_learn['result']

x
# Out:
#          target_date_days               name currency country_of_risk  \
# 365                     1  Ozon Holdings PLC      rub              US
# 366                     2  Ozon Holdings PLC      rub              US
# 367                     3  Ozon Holdings PLC      rub              US
# 368                     4  Ozon Holdings PLC      rub              US
# 369                     5  Ozon Holdings PLC      rub              US
# ...                   ...                ...      ...             ...
# 1262131                11                 ВК      rub              RU
# 1262132                12                 ВК      rub              RU
# 1262133                13                 ВК      rub              RU
# 1262134                14                 ВК      rub              RU
# 1262135                15                 ВК      rub              RU
#
#          forecast_price_change  market_volume        rsi       macd  \
# 365                   0.120449        77121.0  45.765991  87.471558
# 366                   0.120449        77121.0  45.765991  87.471558
# 367                   0.120449        77121.0  45.765991  87.471558
# 368                   0.120449        77121.0  45.765991  87.471558
# 369                   0.120449        77121.0  45.765991  87.471558
# ...                        ...            ...        ...        ...
# 1262131               0.271090      2581180.0  15.229238  -7.203012
# 1262132               0.271090      2581180.0  15.229238  -7.203012
# 1262133               0.271090      2581180.0  15.229238  -7.203012
# 1262134               0.271090      2581180.0  15.229238  -7.203012
# 1262135               0.271090      2581180.0  15.229238  -7.203012
#
#           revenue_ttm    ebitda_ttm  ...  price_change_5_month  \
# 365      6.157320e+11  4.007900e+10  ...             -0.311176
# 366      6.157320e+11  4.007900e+10  ...             -0.311176
# 367      6.157320e+11  4.007900e+10  ...             -0.311176
# 368      6.157320e+11  4.007900e+10  ...             -0.311176
# 369      6.157320e+11  4.007900e+10  ...             -0.311176
# ...               ...           ...  ...                   ...
# 1262131  1.499520e+11  6.212000e+09  ...             -0.143961
# 1262132  1.499520e+11  6.212000e+09  ...             -0.143961
# 1262133  1.499520e+11  6.212000e+09  ...             -0.143961
# 1262134  1.499520e+11  6.212000e+09  ...             -0.143961
# 1262135  1.499520e+11  6.212000e+09  ...             -0.143961
#
#          price_change_6_month  price_change_7_month  price_change_8_month  \
# 365                 -0.162021             -0.217268             -0.038787
# 366                 -0.162021             -0.217268             -0.038787
# 367                 -0.162021             -0.217268             -0.038787
# 368                 -0.162021             -0.217268             -0.038787
# 369                 -0.162021             -0.217268             -0.038787
# ...                       ...                   ...                   ...
# 1262131             -0.082311              0.129011              0.097934
# 1262132             -0.082311              0.129011              0.097934
# 1262133             -0.082311              0.129011              0.097934
# 1262134             -0.082311              0.129011              0.097934
# 1262135             -0.082311              0.129011              0.097934
#
#          price_change_9_month  price_change_10_month  price_change_11_month  \
# 365                  0.084763               0.058464               0.091259
# 366                  0.084763               0.058464               0.091259
# 367                  0.084763               0.058464               0.091259
# 368                  0.084763               0.058464               0.091259
# 369                  0.084763               0.058464               0.091259
# ...                       ...                    ...                    ...
# 1262131              0.040484              -0.144633              -0.017638
# 1262132              0.040484              -0.144633              -0.017638
# 1262133              0.040484              -0.144633              -0.017638
# 1262134              0.040484              -0.144633              -0.017638
# 1262135              0.040484              -0.144633              -0.017638
#
#          price_change_1_year  price_change_2_years  price_change_3_years
# 365                -0.049697             -0.561239             -0.759082
# 366                -0.049697             -0.561239             -0.759082
# 367                -0.049697             -0.561239             -0.759082
# 368                -0.049697             -0.561239             -0.759082
# 369                -0.049697             -0.561239             -0.759082
# ...                      ...                   ...                   ...
# 1262131             0.176214              1.208970              0.174198
# 1262132             0.176214              1.208970              0.174198
# 1262133             0.176214              1.208970              0.174198
# 1262134             0.176214              1.208970              0.174198
# 1262135             0.176214              1.208970              0.174198
#
# [1068207 rows x 75 columns]

# %%
import numpy

x_array = x.values
y_array = y.values
count_samples = len(x_array)

random_indexes = numpy.random.permutation(count_samples)

x_array = x_array[random_indexes]
y_array = y_array[random_indexes]

random_indexes
# Out:
# array([732428, 502151, 527571, ..., 925128, 211069, 339278])

# %%
train_end = int(0.7 * count_samples)
val_end = int(0.9 * count_samples)

x_train, x_val, x_test = numpy.split(x_array, [train_end, val_end])
y_train, y_val, y_test = numpy.split(y_array, [train_end, val_end])

print('X_train shape:', x_train.shape)
print('X_val shape:', x_val.shape)
print('X_test shape:', x_test.shape)

print('Y_train shape:', y_train.shape)
print('Y_val shape:', y_val.shape)
print('Y_test shape:', y_test.shape)
# Out:
# X_train shape: (747744, 75)
# X_val shape: (213642, 75)
# X_test shape: (106821, 75)
# Y_train shape: (747744,)
# Y_val shape: (213642,)
# Y_test shape: (106821,)

# %%
def get_feature_names() -> list:
    return [
        'target_date_days',
        'name',
        'currency',
        'country_of_risk',
        'forecast_price_change',
        'market_volume',
        'rsi',
        'macd',

        'revenue_ttm',
        'ebitda_ttm',
        'market_capitalization',
        'total_debt_mrq',
        'eps_ttm',
        'pe_ratio_ttm',
        'ev_to_ebitda_mrq',
        'dividend_payout_ratio_fy',

        'news_influence_score_0',
        'news_influence_score_1',
        'news_influence_score_2',
        'news_influence_score_3',
        'news_influence_score_4',

        'price_change_2_days_min',
        'price_change_2_days_max',
        'price_change_1_week_min',
        'price_change_1_week_max',
        'price_change_2_week_min',
        'price_change_2_week_max',
        'price_change_3_week_min',
        'price_change_3_week_max',
        'price_change_1_month_min',
        'price_change_1_month_max',
        'price_change_2_month_min',
        'price_change_2_month_max',
        'price_change_3_month_min',
        'price_change_3_month_max',
        'price_change_4_month_min',
        'price_change_4_month_max',
        'price_change_5_month_min',
        'price_change_5_month_max',
        'price_change_6_month_min',
        'price_change_6_month_max',
        'price_change_7_month_min',
        'price_change_7_month_max',
        'price_change_8_month_min',
        'price_change_8_month_max',
        'price_change_9_month_min',
        'price_change_9_month_max',
        'price_change_10_month_min',
        'price_change_10_month_max',
        'price_change_11_month_min',
        'price_change_11_month_max',
        'price_change_1_year_min',
        'price_change_1_year_max',
        'price_change_2_years_min',
        'price_change_2_years_max',
        'price_change_3_years_min',
        'price_change_3_years_max',

        'price_change_2_days',
        'price_change_1_week',
        'price_change_2_week',
        'price_change_3_week',
        'price_change_1_month',
        'price_change_2_month',
        'price_change_3_month',
        'price_change_4_month',
        'price_change_5_month',
        'price_change_6_month',
        'price_change_7_month',
        'price_change_8_month',
        'price_change_9_month',
        'price_change_10_month',
        'price_change_11_month',
        'price_change_1_year',
        'price_change_2_years',
        'price_change_3_years',
    ]

# %%
import catboost

text_features = []
cat_features = ['name', 'currency', 'country_of_risk']

train_pool = catboost.Pool(
    data=x_train,
    label=y_train,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)
validate_pool = catboost.Pool(
    data=x_val,
    label=y_val,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)
test_pool = catboost.Pool(
    data=x_test,
    label=y_test,
    cat_features=cat_features,
    text_features=text_features,
    feature_names=get_feature_names(),
)

test_pool.shape
# Out:
# (106821, 75)

# %% [markdown]
# # Базовая модель

# %%
base_model_file_path = './ta-2_1_base.cbm'
model_base = catboost.CatBoostRegressor().load_model(base_model_file_path)

base_model_rmse_test = model_base.eval_metrics(
    test_pool,
    metrics=['RMSE']
)['RMSE']

sum(base_model_rmse_test) / len(base_model_rmse_test)
# Out:
# 0.027915240173412462

# %% [markdown]
# # Обучение

# %%
model_0 = catboost.CatBoostRegressor(
    task_type='CPU',
    iterations=10_000,
    learning_rate=0.03,
    random_seed=42,
    verbose=100,
    early_stopping_rounds=300,
    eval_metric='RMSE',
    loss_function='RMSE',
    nan_mode='Min',
)

model_0.fit(
    train_pool,
    eval_set=validate_pool,
    plot=False,
)

plt.plot(model_0.get_evals_result()['validation']['RMSE'])
plt.xlabel('Iteration')
plt.ylabel('RMSE')
plt.show()
# Out:
# 0:	learn: 0.0971627	test: 0.0970117	best: 0.0970117 (0)	total: 117ms	remaining: 1m 57s
# 100:	learn: 0.0442562	test: 0.0442742	best: 0.0442742 (100)	total: 11.1s	remaining: 1m 38s
# 200:	learn: 0.0383702	test: 0.0384232	best: 0.0384232 (200)	total: 22s	remaining: 1m 27s
# 300:	learn: 0.0354041	test: 0.0355330	best: 0.0355330 (300)	total: 33s	remaining: 1m 16s
# 400:	learn: 0.0334861	test: 0.0337104	best: 0.0337104 (400)	total: 44.1s	remaining: 1m 5s
# 500:	learn: 0.0320805	test: 0.0323665	best: 0.0323665 (500)	total: 55.2s	remaining: 55s
# 600:	learn: 0.0308981	test: 0.0312196	best: 0.0312196 (600)	total: 1m 6s	remaining: 44s
# 700:	learn: 0.0300149	test: 0.0303948	best: 0.0303948 (700)	total: 1m 17s	remaining: 33.1s

# %%
model_0_file_path = './ta-2_1.cbm'
model_0.save_model(model_0_file_path)

import os

f"{os.path.getsize(model_0_file_path) / 1024 ** 2:.2f} MB"
# Out:
# '0.13 MB'

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, model_0.predict(test_pool))

mse
# Out:
# 0.0018830083186466458

# %%
import numpy as np

rmse = np.sqrt(mse)

rmse
# Out:
# 0.04339364375858112

# %% [markdown]
# ## Метрики для каждой выборки

# %%
rmse_learn = model_0.get_evals_result()['learn']['RMSE']

sum(rmse_learn) / len(rmse_learn)
# Out:
# 0.05231803069760334

# %%
rmse_val = model_0.get_evals_result()['validation']['RMSE']

sum(rmse_val) / len(rmse_val)
# Out:
# 0.052017240260577795

# %%
rmse_test = model_0.eval_metrics(
    test_pool,
    metrics=['RMSE']
)['RMSE']

sum(rmse_test) / len(rmse_test)
# Out:
# 0.05230798583437945

# %%
plt.plot(model_0.get_evals_result()['validation']['RMSE'], label='model_0')
plt.plot(model_base.get_evals_result()['validation']['RMSE'], label='model_base')
plt.legend()
plt.show()
